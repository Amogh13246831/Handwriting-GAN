# %% [markdown]
# <h1>Handwriting Letter GAN</h1>
#
# <h3>Links</h3>
# <ul>
#     <li><a href=https://machinelearningmastery.com/how-to-develop-a-conditional-generative-adversarial-network-from-scratch/>cGAN Code</a></li>
#     <li><a href=https://keras.io/getting-started/functional-api-guide/>Keras Functional API</a></li>
# </ul>

# %%
# !pip install emnist

import numpy as np
from numpy.random import *
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from emnist import *
from skimage import data, io, transform
import matplotlib.pyplot as plt

tf.test.gpu_device_name()
# Out:
# Requirement already satisfied: emnist in /usr/local/lib/python3.6/dist-packages (0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from emnist) (4.38.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from emnist) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from emnist) (1.18.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (1.24.3)
# '/device:GPU:0'

# %%
list_datasets()
# Out:
# ['balanced', 'byclass', 'bymerge', 'digits', 'letters', 'mnist']

# %%
images, labels = extract_training_samples('balanced')
print(images.shape, labels.shape)
#ind = []
#for i in range(20):
#  ind.extend(np.where(labels==i)[0])
#images, labels = images[ind], labels[ind]
#print(images.shape, labels.shape)
plt.imshow(images[0])
print(labels[0])
# Out:
# (112800, 28, 28) (112800,)
# 45

# %%
def define_discriminator(input_shape=(28, 28, 1), n_classes=47):
    # label input and embedding
    label_in = Input(shape=(1, ))
    emb = Embedding(n_classes, 50)(label_in)
    label_h = Dense(input_shape[0] * input_shape[1])(emb)
    re_label_h = Reshape((input_shape[0], input_shape[1], 1))(label_h)
    # image input
    image_in = Input(shape=input_shape)
    # combine inputs
    merge = Concatenate()([image_in, re_label_h])
    # convnet
    h1 = Conv2D(64, (3, 3), strides=(2, 2), padding='same')(merge)
    r1 = LeakyReLU(alpha=0.2)(h1)
    h2 = Conv2D(64, (3, 3), strides=(2, 2), padding='same')(r1)
    r2 = LeakyReLU(alpha=0.2)(h2)
    # fully connected net
    fl = Flatten()(r2) 
    dr = Dropout(0.4)(fl)
    # output
    out = Dense(1, activation='sigmoid')(dr)
    # define and compile model
    model = Model([image_in, label_in], out)
    opt = Adam(lr=2e-4, beta_1=0.5)
    model.compile(loss='mse', optimizer=opt, metrics=['accuracy'])
    return model

# %%
def define_generator(latent_dim, n_classes=47):
    # label input and embedding
    label_in = Input(shape=(1, ))
    emb = Embedding(n_classes, 50)(label_in)
    label_h = Dense(7*7)(emb)
    re_label_h = Reshape((7, 7, 1))(label_h)
    # noisy image input
    noise_in = Input(shape=(latent_dim,))
    noise_h = Dense(128*7*7)(noise_in)
    noise_r = LeakyReLU(alpha=0.2)(noise_h)
    re_noise_r = Reshape((7, 7, 128))(noise_r)
    # combine inputs
    merge = Concatenate()([re_noise_r, re_label_h])
    # upsampling
    u1 = Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same')(merge)
    r1 = LeakyReLU(alpha=0.2)(u1)
    u2 = Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same')(r1)
    r2 = LeakyReLU(alpha=0.2)(u2)
    # output
    out = Conv2D(1, (7, 7), activation='tanh', padding='same')(r2)
    # define model
    model = Model([noise_in, label_in], out)
    return model

# %%
def define_gan(gen, dis):
    # discriminator shouldn't be trainable
    dis.trainable = False
    # get generator inputs and outputs
    gen_noise, gen_label = gen.input
    gen_output = gen.output
    # feed to discriminator
    gan_output = dis([gen_output, gen_label])
    # define and compile GAN model
    model = Model([gen_noise, gen_label], gan_output)
    opt = Adam(lr=2e-4, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=opt)
    return model

# %%
def prepare_inputs(images, labels):
    if len(images.shape) > 2:
      images = np.squeeze(images)
    X = np.expand_dims(images, axis=-1)
    X = X.astype('float32')
    X = (X-127.5) / 127.5
    return [X, labels]
    
def generate_real_samples(images, labels, n_samples):
    rand_index = randint(0, images.shape[0], n_samples)
    X, labels = images[rand_index], labels[rand_index]
    y = np.ones((n_samples, 1)) * 0.9 # discriminator target label
    # label smoothing
    #ind = np.random.choice(list(range(len(y))), size=int(len(y) * 0.01), replace=False)
    #y[ind] = 1-y[ind]
    return [X, labels], y

def generate_latent_noise(latent_dim, n_samples, n_classes=47):
    xin = randn(latent_dim * n_samples)
    xin = xin.reshape(n_samples, latent_dim)
    labels = randint(0, n_classes, n_samples)  #  generator class label
    return xin, labels

def generate_fake_samples(gen, latent_dim, n_samples):
    zin, lin = generate_latent_noise(latent_dim, n_samples)
    images = gen.predict([zin, lin])
    y = np.zeros((n_samples, 1))  # discriminator target label
    # label smoothing
    #ind = np.random.choice(list(range(len(y))), size=int(len(y) * 0.01), replace=False)
    #y[ind] = 1-y[ind]
    return [images, lin], y

# %%
def train_gan(gen, dis, gan_model, images, labels, latent_dim, n_epochs=100, batch_size=128):
    batch_per_epoch = int(images.shape[0] / batch_size)
    half_batch = int(batch_size / 2)
    # enumerate epochs
    for i in range(n_epochs):
        for j in range(batch_per_epoch):
            # train discriminator on real images
            [X_real, labels_real], y_real = generate_real_samples(images, labels, half_batch)
            d_loss1, _ = dis.train_on_batch([X_real, labels_real], y_real)
            # train discriminator on generated images
            [X_fake, labels_fake], y_fake = generate_fake_samples(gen, latent_dim, half_batch)
            #d_loss2 = dis.evaluate([X_fake, labels_fake], y_fake)[0]
            #if d_loss2 > 0.5:
            d_loss2, _ = dis.train_on_batch([X_fake, labels_fake], y_fake)
            # prepare generator input
            [zin, label_in] = generate_latent_noise(latent_dim, batch_size)
            # invert labels for fake samples (prevent vanishing gradients)
            y_gan = np.ones((batch_size, 1))
            # label smoothing
            #ind = np.random.choice(list(range(len(y_gan))), size=int(len(y_gan) * 0.01), replace=False)
            #y_gan[ind] = 1-y_gan[ind]
            # update generator loss
            g_loss = gan_model.train_on_batch([zin, label_in], y_gan)
            # output losses
            if j % 50 == 0:
              print('Epoch {}, batch {}/{}:\tDiscriminator: real loss {}, fake loss {}\tGenerator: loss {}'
                  .format(i+1, j+1, batch_per_epoch, d_loss1, d_loss2, g_loss))
    # save the models
    gen.save('generator.h5')
    dis.save('discriminator.h5')
    gan_model.save('gan.h5')

# %%
latent_dim = 500
images, labels = prepare_inputs(images, labels)
print(images.shape, labels.shape)
dis = define_discriminator()
gen = define_generator(latent_dim)
gan_model = define_gan(gen, dis)
print("\nDiscriminator\n")
dis.summary()
print("\nGenerator\n")
gen.summary()
print("\nGAN\n")
gan_model.summary()
# Out:
# (112800, 28, 28, 1) (112800,)
#
# Discriminator
#
# Model: "model_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_13 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding_6 (Embedding)         (None, 1, 50)        2350        input_13[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1, 784)       39984       embedding_6[0][0]
# __________________________________________________________________________________________________
# input_14 (InputLayer)           [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 28, 28, 1)    0           dense_12[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 28, 28, 2)    0           input_14[0][0]
#                                                                  reshape_9[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 14, 14, 64)   1216        concatenate_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 14, 14, 64)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 7, 7, 64)     36928       leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 7, 7, 64)     0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 3136)         0           leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 3136)         0           flatten_3[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 1)            3137        dropout_3[0][0]
# ==================================================================================================
# Total params: 83,615
# Trainable params: 0
# Non-trainable params: 83,615
# __________________________________________________________________________________________________
#
# Generator
#
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_16 (InputLayer)           [(None, 500)]        0
# __________________________________________________________________________________________________
# input_15 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 6272)         3142272     input_16[0][0]
# __________________________________________________________________________________________________
# embedding_7 (Embedding)         (None, 1, 50)        2350        input_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 6272)         0           dense_15[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 1, 49)        2499        embedding_7[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 7, 7, 128)    0           leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 7, 7, 1)      0           dense_14[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 7, 7, 129)    0           reshape_11[0][0]
#                                                                  reshape_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 14, 14, 128)  264320      concatenate_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 14, 14, 128)  0           conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 28, 28, 128)  262272      leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 28, 28, 128)  0           conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 1)    6273        leaky_re_lu_19[0][0]
# ==================================================================================================
# Total params: 3,679,986
# Trainable params: 3,679,986
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# GAN
#
# Model: "model_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_16 (InputLayer)           [(None, 500)]        0
# __________________________________________________________________________________________________
# input_15 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 6272)         3142272     input_16[0][0]
# __________________________________________________________________________________________________
# embedding_7 (Embedding)         (None, 1, 50)        2350        input_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 6272)         0           dense_15[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 1, 49)        2499        embedding_7[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 7, 7, 128)    0           leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 7, 7, 1)      0           dense_14[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 7, 7, 129)    0           reshape_11[0][0]
#                                                                  reshape_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 14, 14, 128)  264320      concatenate_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 14, 14, 128)  0           conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 28, 28, 128)  262272      leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 28, 28, 128)  0           conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 1)    6273        leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# model_9 (Model)                 (None, 1)            83615       conv2d_11[0][0]
#                                                                  input_15[0][0]
# ==================================================================================================
# Total params: 3,763,601
# Trainable params: 3,679,986
# Non-trainable params: 83,615
# __________________________________________________________________________________________________

# %%
train_gan(gen, dis, gan_model, images, labels, latent_dim, n_epochs=100, batch_size=128)
# Out:
# Epoch 1, batch 1/881:	Discriminator: real loss 0.16889889538288116, fake loss 0.2502649426460266	Generator: loss 0.693526566028595
# Epoch 1, batch 51/881:	Discriminator: real loss 0.06504085659980774, fake loss 0.1612352430820465	Generator: loss 0.9825058579444885
# Epoch 1, batch 101/881:	Discriminator: real loss 0.19233599305152893, fake loss 0.2330618053674698	Generator: loss 0.8187123537063599
# Epoch 1, batch 151/881:	Discriminator: real loss 0.20618140697479248, fake loss 0.21306273341178894	Generator: loss 0.8288794159889221
# Epoch 1, batch 201/881:	Discriminator: real loss 0.20000721514225006, fake loss 0.22197309136390686	Generator: loss 0.8037288188934326
# Epoch 1, batch 251/881:	Discriminator: real loss 0.21160408854484558, fake loss 0.2131478488445282	Generator: loss 0.8219045400619507
# Epoch 1, batch 301/881:	Discriminator: real loss 0.20600920915603638, fake loss 0.21442748606204987	Generator: loss 0.8079257607460022
# Epoch 1, batch 351/881:	Discriminator: real loss 0.20483660697937012, fake loss 0.20706021785736084	Generator: loss 0.8238815069198608
# Epoch 1, batch 401/881:	Discriminator: real loss 0.2035915106534958, fake loss 0.22648583352565765	Generator: loss 0.7839032411575317
# Epoch 1, batch 451/881:	Discriminator: real loss 0.2075663059949875, fake loss 0.20249199867248535	Generator: loss 0.812627911567688
# Epoch 1, batch 501/881:	Discriminator: real loss 0.19860130548477173, fake loss 0.21704502403736115	Generator: loss 0.7853657603263855
# Epoch 1, batch 551/881:	Discriminator: real loss 0.20932647585868835, fake loss 0.20597529411315918	Generator: loss 0.8365370631217957
# Epoch 1, batch 601/881:	Discriminator: real loss 0.20447532832622528, fake loss 0.20635470747947693	Generator: loss 0.8168817758560181
# Epoch 1, batch 651/881:	Discriminator: real loss 0.1982569396495819, fake loss 0.21140508353710175	Generator: loss 0.813446044921875
# Epoch 1, batch 701/881:	Discriminator: real loss 0.20138832926750183, fake loss 0.21425777673721313	Generator: loss 0.7996265888214111
# Epoch 1, batch 751/881:	Discriminator: real loss 0.2015395164489746, fake loss 0.22089554369449615	Generator: loss 0.7867276668548584
# Epoch 1, batch 801/881:	Discriminator: real loss 0.2050943672657013, fake loss 0.2090500295162201	Generator: loss 0.802564263343811
# Epoch 1, batch 851/881:	Discriminator: real loss 0.1940159946680069, fake loss 0.213731050491333	Generator: loss 0.7973317503929138
# Epoch 2, batch 1/881:	Discriminator: real loss 0.1963350772857666, fake loss 0.2070583701133728	Generator: loss 0.7935283184051514
# Epoch 2, batch 51/881:	Discriminator: real loss 0.19760483503341675, fake loss 0.20835718512535095	Generator: loss 0.802111804485321
# Epoch 2, batch 101/881:	Discriminator: real loss 0.20097213983535767, fake loss 0.1878320723772049	Generator: loss 0.8538230657577515
# Epoch 2, batch 151/881:	Discriminator: real loss 0.1988602578639984, fake loss 0.21961760520935059	Generator: loss 0.7948035001754761
# Epoch 2, batch 201/881:	Discriminator: real loss 0.20130345225334167, fake loss 0.18726663291454315	Generator: loss 0.8598649501800537
# Epoch 2, batch 251/881:	Discriminator: real loss 0.19528526067733765, fake loss 0.20619282126426697	Generator: loss 0.796414315700531
# Epoch 2, batch 301/881:	Discriminator: real loss 0.19410854578018188, fake loss 0.19538256525993347	Generator: loss 0.8304075598716736
# Epoch 2, batch 351/881:	Discriminator: real loss 0.20054754614830017, fake loss 0.20182940363883972	Generator: loss 0.809829592704773
# Epoch 2, batch 401/881:	Discriminator: real loss 0.1918151080608368, fake loss 0.20334191620349884	Generator: loss 0.8180774450302124
# Epoch 2, batch 451/881:	Discriminator: real loss 0.18741710484027863, fake loss 0.2013729065656662	Generator: loss 0.8319239616394043
# Epoch 2, batch 501/881:	Discriminator: real loss 0.18738266825675964, fake loss 0.21836721897125244	Generator: loss 0.8044801950454712
# Epoch 2, batch 551/881:	Discriminator: real loss 0.18703895807266235, fake loss 0.17608797550201416	Generator: loss 0.889249324798584
# Epoch 2, batch 601/881:	Discriminator: real loss 0.18323667347431183, fake loss 0.19346563518047333	Generator: loss 0.8490864038467407
# Epoch 2, batch 651/881:	Discriminator: real loss 0.19082777202129364, fake loss 0.20210152864456177	Generator: loss 0.8103064298629761
# Epoch 2, batch 701/881:	Discriminator: real loss 0.19391317665576935, fake loss 0.2169073522090912	Generator: loss 0.7981290817260742
# Epoch 2, batch 751/881:	Discriminator: real loss 0.19528397917747498, fake loss 0.19609728455543518	Generator: loss 0.8264760971069336
# Epoch 2, batch 801/881:	Discriminator: real loss 0.18898409605026245, fake loss 0.20620855689048767	Generator: loss 0.81475830078125
# Epoch 2, batch 851/881:	Discriminator: real loss 0.1931370496749878, fake loss 0.20221927762031555	Generator: loss 0.8183083534240723
# Epoch 3, batch 1/881:	Discriminator: real loss 0.19668346643447876, fake loss 0.1916324496269226	Generator: loss 0.8338913917541504
# Epoch 3, batch 51/881:	Discriminator: real loss 0.1971813440322876, fake loss 0.17648161947727203	Generator: loss 0.9013485312461853
# Epoch 3, batch 101/881:	Discriminator: real loss 0.18949414789676666, fake loss 0.18911044299602509	Generator: loss 0.8383359909057617
# Epoch 3, batch 151/881:	Discriminator: real loss 0.1860106885433197, fake loss 0.2133030891418457	Generator: loss 0.8214666247367859
# Epoch 3, batch 201/881:	Discriminator: real loss 0.1976461559534073, fake loss 0.20202898979187012	Generator: loss 0.8377207517623901
# Epoch 3, batch 251/881:	Discriminator: real loss 0.19437116384506226, fake loss 0.20625099539756775	Generator: loss 0.8239791393280029
# Epoch 3, batch 301/881:	Discriminator: real loss 0.19617360830307007, fake loss 0.19513894617557526	Generator: loss 0.8283932209014893
# Epoch 3, batch 351/881:	Discriminator: real loss 0.19098249077796936, fake loss 0.20350974798202515	Generator: loss 0.826974630355835
# Epoch 3, batch 401/881:	Discriminator: real loss 0.19582197070121765, fake loss 0.19597168266773224	Generator: loss 0.8258700966835022
# Epoch 3, batch 451/881:	Discriminator: real loss 0.19709640741348267, fake loss 0.20301367342472076	Generator: loss 0.8199562430381775
# Epoch 3, batch 501/881:	Discriminator: real loss 0.20107483863830566, fake loss 0.20414228737354279	Generator: loss 0.8101062774658203
# Epoch 3, batch 551/881:	Discriminator: real loss 0.2056879848241806, fake loss 0.20383107662200928	Generator: loss 0.8260952234268188
# Epoch 3, batch 601/881:	Discriminator: real loss 0.19931617379188538, fake loss 0.20207057893276215	Generator: loss 0.82724928855896
# Epoch 3, batch 651/881:	Discriminator: real loss 0.1921846866607666, fake loss 0.20031198859214783	Generator: loss 0.825041651725769
# Epoch 3, batch 701/881:	Discriminator: real loss 0.19645100831985474, fake loss 0.19947506487369537	Generator: loss 0.8244966268539429
# Epoch 3, batch 751/881:	Discriminator: real loss 0.20365342497825623, fake loss 0.1980961561203003	Generator: loss 0.8263604640960693
# Epoch 3, batch 801/881:	Discriminator: real loss 0.1982409507036209, fake loss 0.20199242234230042	Generator: loss 0.8389897346496582
# Epoch 3, batch 851/881:	Discriminator: real loss 0.19910424947738647, fake loss 0.20171870291233063	Generator: loss 0.8259220123291016
# Epoch 4, batch 1/881:	Discriminator: real loss 0.19949433207511902, fake loss 0.19702978432178497	Generator: loss 0.8258184194564819
# Epoch 4, batch 51/881:	Discriminator: real loss 0.20053406059741974, fake loss 0.20133700966835022	Generator: loss 0.8421142101287842
# Epoch 4, batch 101/881:	Discriminator: real loss 0.19195841252803802, fake loss 0.19730965793132782	Generator: loss 0.8416069746017456
# Epoch 4, batch 151/881:	Discriminator: real loss 0.2000574767589569, fake loss 0.20625129342079163	Generator: loss 0.8169587850570679
# Epoch 4, batch 201/881:	Discriminator: real loss 0.1843658983707428, fake loss 0.20878079533576965	Generator: loss 0.8178133368492126
# Epoch 4, batch 251/881:	Discriminator: real loss 0.19750583171844482, fake loss 0.1967362016439438	Generator: loss 0.8428679704666138
# Epoch 4, batch 301/881:	Discriminator: real loss 0.20111817121505737, fake loss 0.17938217520713806	Generator: loss 0.8866812586784363
# Epoch 4, batch 351/881:	Discriminator: real loss 0.199821338057518, fake loss 0.2049037218093872	Generator: loss 0.8077483177185059
# Epoch 4, batch 401/881:	Discriminator: real loss 0.19981178641319275, fake loss 0.19918927550315857	Generator: loss 0.8396174907684326
# Epoch 4, batch 451/881:	Discriminator: real loss 0.18925507366657257, fake loss 0.17286401987075806	Generator: loss 0.902060866355896
# Epoch 4, batch 501/881:	Discriminator: real loss 0.19879333674907684, fake loss 0.1972719430923462	Generator: loss 0.8455948829650879
# Epoch 4, batch 551/881:	Discriminator: real loss 0.19578751921653748, fake loss 0.20315174758434296	Generator: loss 0.8219282627105713
# Epoch 4, batch 601/881:	Discriminator: real loss 0.1916617602109909, fake loss 0.2064109742641449	Generator: loss 0.8385595083236694
# Epoch 4, batch 651/881:	Discriminator: real loss 0.20716509222984314, fake loss 0.2033194601535797	Generator: loss 0.8238116502761841
# Epoch 4, batch 701/881:	Discriminator: real loss 0.1981426626443863, fake loss 0.22219499945640564	Generator: loss 0.781863808631897
# Epoch 4, batch 751/881:	Discriminator: real loss 0.19755113124847412, fake loss 0.21330058574676514	Generator: loss 0.8013843297958374
# Epoch 4, batch 801/881:	Discriminator: real loss 0.19974695146083832, fake loss 0.19688424468040466	Generator: loss 0.8679854869842529
# Epoch 4, batch 851/881:	Discriminator: real loss 0.20314931869506836, fake loss 0.18267548084259033	Generator: loss 0.889833927154541
# Epoch 5, batch 1/881:	Discriminator: real loss 0.19700756669044495, fake loss 0.21838447451591492	Generator: loss 0.7795242071151733
# Epoch 5, batch 51/881:	Discriminator: real loss 0.20551691949367523, fake loss 0.20614251494407654	Generator: loss 0.8146585822105408
# Epoch 5, batch 101/881:	Discriminator: real loss 0.1923949420452118, fake loss 0.1987198293209076	Generator: loss 0.8079127073287964
# Epoch 5, batch 151/881:	Discriminator: real loss 0.1924101561307907, fake loss 0.18879784643650055	Generator: loss 0.8743484020233154
# Epoch 5, batch 201/881:	Discriminator: real loss 0.20293228328227997, fake loss 0.1801750361919403	Generator: loss 0.9164316654205322
# Epoch 5, batch 251/881:	Discriminator: real loss 0.18798434734344482, fake loss 0.1951533854007721	Generator: loss 0.8494300246238708
# Epoch 5, batch 301/881:	Discriminator: real loss 0.19261574745178223, fake loss 0.21047955751419067	Generator: loss 0.8242301940917969
# Epoch 5, batch 351/881:	Discriminator: real loss 0.20061388611793518, fake loss 0.21821975708007812	Generator: loss 0.8137423396110535
# Epoch 5, batch 401/881:	Discriminator: real loss 0.19608832895755768, fake loss 0.21308085322380066	Generator: loss 0.8231556415557861
# Epoch 5, batch 451/881:	Discriminator: real loss 0.20114082098007202, fake loss 0.1902761161327362	Generator: loss 0.8521878123283386
# Epoch 5, batch 501/881:	Discriminator: real loss 0.20780453085899353, fake loss 0.1852230578660965	Generator: loss 0.8579580783843994
# Epoch 5, batch 551/881:	Discriminator: real loss 0.2020048201084137, fake loss 0.20001202821731567	Generator: loss 0.8281484842300415
# Epoch 5, batch 601/881:	Discriminator: real loss 0.1909700334072113, fake loss 0.19174543023109436	Generator: loss 0.8454158306121826
# Epoch 5, batch 651/881:	Discriminator: real loss 0.2000986486673355, fake loss 0.20105524361133575	Generator: loss 0.8283216953277588
# Epoch 5, batch 701/881:	Discriminator: real loss 0.1991545408964157, fake loss 0.1941414326429367	Generator: loss 0.8544092178344727
# Epoch 5, batch 751/881:	Discriminator: real loss 0.1893857717514038, fake loss 0.1930212527513504	Generator: loss 0.8491112589836121
# Epoch 5, batch 801/881:	Discriminator: real loss 0.19604948163032532, fake loss 0.18490254878997803	Generator: loss 0.8563558459281921
# Epoch 5, batch 851/881:	Discriminator: real loss 0.18822771310806274, fake loss 0.2008214294910431	Generator: loss 0.8411873579025269
# Epoch 6, batch 1/881:	Discriminator: real loss 0.19896140694618225, fake loss 0.193502739071846	Generator: loss 0.834388256072998
# Epoch 6, batch 51/881:	Discriminator: real loss 0.19638557732105255, fake loss 0.22536572813987732	Generator: loss 0.8154414892196655
# Epoch 6, batch 101/881:	Discriminator: real loss 0.20252175629138947, fake loss 0.19665339589118958	Generator: loss 0.8316711187362671
# Epoch 6, batch 151/881:	Discriminator: real loss 0.19940942525863647, fake loss 0.19683130085468292	Generator: loss 0.8390733599662781
# Epoch 6, batch 201/881:	Discriminator: real loss 0.19290034472942352, fake loss 0.19398677349090576	Generator: loss 0.8257050514221191
# Epoch 6, batch 251/881:	Discriminator: real loss 0.1985582560300827, fake loss 0.20044568181037903	Generator: loss 0.8390922546386719
# Epoch 6, batch 301/881:	Discriminator: real loss 0.2021249234676361, fake loss 0.1935506910085678	Generator: loss 0.8326351642608643
# Epoch 6, batch 351/881:	Discriminator: real loss 0.1888064593076706, fake loss 0.2115982472896576	Generator: loss 0.8108141422271729
# Epoch 6, batch 401/881:	Discriminator: real loss 0.18926402926445007, fake loss 0.19258220493793488	Generator: loss 0.8374691009521484
# Epoch 6, batch 451/881:	Discriminator: real loss 0.1925768256187439, fake loss 0.19766713678836823	Generator: loss 0.8386927843093872
# Epoch 6, batch 501/881:	Discriminator: real loss 0.19529739022254944, fake loss 0.20641863346099854	Generator: loss 0.8364336490631104
# Epoch 6, batch 551/881:	Discriminator: real loss 0.2018919587135315, fake loss 0.19941595196723938	Generator: loss 0.829531192779541
# Epoch 6, batch 601/881:	Discriminator: real loss 0.19669274985790253, fake loss 0.20276972651481628	Generator: loss 0.8153257966041565
# Epoch 6, batch 651/881:	Discriminator: real loss 0.1916555017232895, fake loss 0.19525231420993805	Generator: loss 0.8291528224945068
# Epoch 6, batch 701/881:	Discriminator: real loss 0.19563409686088562, fake loss 0.19790062308311462	Generator: loss 0.831466555595398
# Epoch 6, batch 751/881:	Discriminator: real loss 0.18991702795028687, fake loss 0.20264682173728943	Generator: loss 0.834659993648529
# Epoch 6, batch 801/881:	Discriminator: real loss 0.187771737575531, fake loss 0.19403177499771118	Generator: loss 0.8332904577255249
# Epoch 6, batch 851/881:	Discriminator: real loss 0.1944761425256729, fake loss 0.19540247321128845	Generator: loss 0.84483802318573
# Epoch 7, batch 1/881:	Discriminator: real loss 0.1891983300447464, fake loss 0.20317015051841736	Generator: loss 0.8400765061378479
# Epoch 7, batch 51/881:	Discriminator: real loss 0.1877814084291458, fake loss 0.20933794975280762	Generator: loss 0.8389421701431274
# Epoch 7, batch 101/881:	Discriminator: real loss 0.19033148884773254, fake loss 0.19765281677246094	Generator: loss 0.8482767939567566
# Epoch 7, batch 151/881:	Discriminator: real loss 0.20061418414115906, fake loss 0.1987248957157135	Generator: loss 0.8321619033813477
# Epoch 7, batch 201/881:	Discriminator: real loss 0.1914125382900238, fake loss 0.20114946365356445	Generator: loss 0.8496041297912598
# Epoch 7, batch 251/881:	Discriminator: real loss 0.1908522993326187, fake loss 0.18320119380950928	Generator: loss 0.8572918176651001
# Epoch 7, batch 301/881:	Discriminator: real loss 0.20102787017822266, fake loss 0.2017804980278015	Generator: loss 0.8443039059638977
# Epoch 7, batch 351/881:	Discriminator: real loss 0.19410836696624756, fake loss 0.19891895353794098	Generator: loss 0.8426012992858887
# Epoch 7, batch 401/881:	Discriminator: real loss 0.19329173862934113, fake loss 0.20173585414886475	Generator: loss 0.8433646559715271
# Epoch 7, batch 451/881:	Discriminator: real loss 0.19291995465755463, fake loss 0.1969417929649353	Generator: loss 0.8354870080947876
# Epoch 7, batch 501/881:	Discriminator: real loss 0.19271762669086456, fake loss 0.19048091769218445	Generator: loss 0.8624718189239502
# Epoch 7, batch 551/881:	Discriminator: real loss 0.192527174949646, fake loss 0.20067059993743896	Generator: loss 0.8366219401359558
# Epoch 7, batch 601/881:	Discriminator: real loss 0.19212374091148376, fake loss 0.19519877433776855	Generator: loss 0.8474356532096863
# Epoch 7, batch 651/881:	Discriminator: real loss 0.19176258146762848, fake loss 0.20312055945396423	Generator: loss 0.8450611233711243
# Epoch 7, batch 701/881:	Discriminator: real loss 0.19773855805397034, fake loss 0.19480794668197632	Generator: loss 0.8437888622283936
# Epoch 7, batch 751/881:	Discriminator: real loss 0.19403445720672607, fake loss 0.19616419076919556	Generator: loss 0.8396146297454834
# Epoch 7, batch 801/881:	Discriminator: real loss 0.1814776510000229, fake loss 0.1960655003786087	Generator: loss 0.8254047632217407
# Epoch 7, batch 851/881:	Discriminator: real loss 0.19663943350315094, fake loss 0.18984556198120117	Generator: loss 0.8589191436767578
# Epoch 8, batch 1/881:	Discriminator: real loss 0.1968259960412979, fake loss 0.18533794581890106	Generator: loss 0.8616555333137512
# Epoch 8, batch 51/881:	Discriminator: real loss 0.1970425546169281, fake loss 0.20037220418453217	Generator: loss 0.8545362949371338
# Epoch 8, batch 101/881:	Discriminator: real loss 0.18985222280025482, fake loss 0.20695021748542786	Generator: loss 0.8516457676887512
# Epoch 8, batch 151/881:	Discriminator: real loss 0.19412969052791595, fake loss 0.18938791751861572	Generator: loss 0.8441781997680664
# Epoch 8, batch 201/881:	Discriminator: real loss 0.20240455865859985, fake loss 0.20211398601531982	Generator: loss 0.8468574285507202
# Epoch 8, batch 251/881:	Discriminator: real loss 0.19207650423049927, fake loss 0.20332500338554382	Generator: loss 0.844767153263092
# Epoch 8, batch 301/881:	Discriminator: real loss 0.1987546980381012, fake loss 0.1935025155544281	Generator: loss 0.8542699813842773
# Epoch 8, batch 351/881:	Discriminator: real loss 0.19025325775146484, fake loss 0.19950881600379944	Generator: loss 0.84922856092453
# Epoch 8, batch 401/881:	Discriminator: real loss 0.19602292776107788, fake loss 0.20306679606437683	Generator: loss 0.8484975099563599
# Epoch 8, batch 451/881:	Discriminator: real loss 0.19661357998847961, fake loss 0.1990346908569336	Generator: loss 0.8630043268203735
# Epoch 8, batch 501/881:	Discriminator: real loss 0.18613620102405548, fake loss 0.21216018497943878	Generator: loss 0.8635879755020142
# Epoch 8, batch 551/881:	Discriminator: real loss 0.19860881567001343, fake loss 0.20415475964546204	Generator: loss 0.8637958765029907
# Epoch 8, batch 601/881:	Discriminator: real loss 0.19364233314990997, fake loss 0.20307767391204834	Generator: loss 0.8613500595092773
# Epoch 8, batch 651/881:	Discriminator: real loss 0.19054627418518066, fake loss 0.18849405646324158	Generator: loss 0.8483930826187134
# Epoch 8, batch 701/881:	Discriminator: real loss 0.18933522701263428, fake loss 0.19135981798171997	Generator: loss 0.8508548736572266
# Epoch 8, batch 751/881:	Discriminator: real loss 0.18612509965896606, fake loss 0.19906717538833618	Generator: loss 0.8733124732971191
# Epoch 8, batch 801/881:	Discriminator: real loss 0.19638603925704956, fake loss 0.21583355963230133	Generator: loss 0.875891923904419
# Epoch 8, batch 851/881:	Discriminator: real loss 0.18718212842941284, fake loss 0.20084379613399506	Generator: loss 0.8616571426391602
# Epoch 9, batch 1/881:	Discriminator: real loss 0.19368582963943481, fake loss 0.19969595968723297	Generator: loss 0.8481292724609375
# Epoch 9, batch 51/881:	Discriminator: real loss 0.1934148669242859, fake loss 0.1934012621641159	Generator: loss 0.8422893285751343
# Epoch 9, batch 101/881:	Discriminator: real loss 0.17531076073646545, fake loss 0.18856337666511536	Generator: loss 0.8678320646286011
# Epoch 9, batch 151/881:	Discriminator: real loss 0.19003012776374817, fake loss 0.19616132974624634	Generator: loss 0.8832571506500244
# Epoch 9, batch 201/881:	Discriminator: real loss 0.18916203081607819, fake loss 0.19687485694885254	Generator: loss 0.8506736755371094
# Epoch 9, batch 251/881:	Discriminator: real loss 0.1928832232952118, fake loss 0.19326291978359222	Generator: loss 0.8387431502342224
# Epoch 9, batch 301/881:	Discriminator: real loss 0.18647927045822144, fake loss 0.1917629837989807	Generator: loss 0.8680950403213501
# Epoch 9, batch 351/881:	Discriminator: real loss 0.19600141048431396, fake loss 0.20110777020454407	Generator: loss 0.876530647277832
# Epoch 9, batch 401/881:	Discriminator: real loss 0.19765087962150574, fake loss 0.1941256821155548	Generator: loss 0.8535658121109009
# Epoch 9, batch 451/881:	Discriminator: real loss 0.20141981542110443, fake loss 0.1916683316230774	Generator: loss 0.873185396194458
# Epoch 9, batch 501/881:	Discriminator: real loss 0.19836533069610596, fake loss 0.18141084909439087	Generator: loss 0.858810305595398
# Epoch 9, batch 551/881:	Discriminator: real loss 0.19923174381256104, fake loss 0.19622087478637695	Generator: loss 0.849774181842804
# Epoch 9, batch 601/881:	Discriminator: real loss 0.18773536384105682, fake loss 0.18484050035476685	Generator: loss 0.8915039896965027
# Epoch 9, batch 651/881:	Discriminator: real loss 0.19213521480560303, fake loss 0.20169569551944733	Generator: loss 0.8665257692337036
# Epoch 9, batch 701/881:	Discriminator: real loss 0.1823463886976242, fake loss 0.20549191534519196	Generator: loss 0.8428030014038086
# Epoch 9, batch 751/881:	Discriminator: real loss 0.1988375186920166, fake loss 0.20253317058086395	Generator: loss 0.8409043550491333
# Epoch 9, batch 801/881:	Discriminator: real loss 0.1950177550315857, fake loss 0.19612440466880798	Generator: loss 0.8574596643447876
# Epoch 9, batch 851/881:	Discriminator: real loss 0.19203199446201324, fake loss 0.20029973983764648	Generator: loss 0.8874734044075012
# Epoch 10, batch 1/881:	Discriminator: real loss 0.2016623467206955, fake loss 0.2068376988172531	Generator: loss 0.8487412333488464
# Epoch 10, batch 51/881:	Discriminator: real loss 0.19010697305202484, fake loss 0.18902207911014557	Generator: loss 0.874549388885498
# Epoch 10, batch 101/881:	Discriminator: real loss 0.18922026455402374, fake loss 0.19965529441833496	Generator: loss 0.894331157207489
# Epoch 10, batch 151/881:	Discriminator: real loss 0.18904396891593933, fake loss 0.19541722536087036	Generator: loss 0.8575310111045837
# Epoch 10, batch 201/881:	Discriminator: real loss 0.16851481795310974, fake loss 0.195644348859787	Generator: loss 0.8812903761863708
# Epoch 10, batch 251/881:	Discriminator: real loss 0.18582823872566223, fake loss 0.20143216848373413	Generator: loss 0.8596194386482239
# Epoch 10, batch 301/881:	Discriminator: real loss 0.19599078595638275, fake loss 0.2070193588733673	Generator: loss 0.8809412717819214
# Epoch 10, batch 351/881:	Discriminator: real loss 0.2046860158443451, fake loss 0.19194652140140533	Generator: loss 0.8785334825515747
# Epoch 10, batch 401/881:	Discriminator: real loss 0.18827715516090393, fake loss 0.20343948900699615	Generator: loss 0.8723859190940857
# Epoch 10, batch 451/881:	Discriminator: real loss 0.1931532770395279, fake loss 0.20149114727973938	Generator: loss 0.9107975959777832
# Epoch 10, batch 501/881:	Discriminator: real loss 0.18191245198249817, fake loss 0.18817749619483948	Generator: loss 0.8742944002151489
# Epoch 10, batch 551/881:	Discriminator: real loss 0.188937246799469, fake loss 0.1981697380542755	Generator: loss 0.889984130859375
# Epoch 10, batch 601/881:	Discriminator: real loss 0.19751635193824768, fake loss 0.19591423869132996	Generator: loss 0.8501556515693665
# Epoch 10, batch 651/881:	Discriminator: real loss 0.1800251454114914, fake loss 0.19651532173156738	Generator: loss 0.8681864738464355
# Epoch 10, batch 701/881:	Discriminator: real loss 0.20115545392036438, fake loss 0.20005619525909424	Generator: loss 0.8540434837341309
# Epoch 10, batch 751/881:	Discriminator: real loss 0.196829155087471, fake loss 0.17870911955833435	Generator: loss 0.8738229870796204
# Epoch 10, batch 801/881:	Discriminator: real loss 0.18935489654541016, fake loss 0.19390717148780823	Generator: loss 0.8890000581741333
# Epoch 10, batch 851/881:	Discriminator: real loss 0.19982296228408813, fake loss 0.20064426958560944	Generator: loss 0.8644204139709473
# Epoch 11, batch 1/881:	Discriminator: real loss 0.19454419612884521, fake loss 0.19762249290943146	Generator: loss 0.8564425110816956
# Epoch 11, batch 51/881:	Discriminator: real loss 0.19824232161045074, fake loss 0.1933986246585846	Generator: loss 0.8819188475608826
# Epoch 11, batch 101/881:	Discriminator: real loss 0.19616642594337463, fake loss 0.2043410688638687	Generator: loss 0.8623782992362976
# Epoch 11, batch 151/881:	Discriminator: real loss 0.20454519987106323, fake loss 0.1979680359363556	Generator: loss 0.880957841873169
# Epoch 11, batch 201/881:	Discriminator: real loss 0.1885484755039215, fake loss 0.19873443245887756	Generator: loss 0.868211030960083
# Epoch 11, batch 251/881:	Discriminator: real loss 0.19058743119239807, fake loss 0.1893380880355835	Generator: loss 0.8736863136291504
# Epoch 11, batch 301/881:	Discriminator: real loss 0.1941804587841034, fake loss 0.19039613008499146	Generator: loss 0.8521283864974976
# Epoch 11, batch 351/881:	Discriminator: real loss 0.19553925096988678, fake loss 0.19029466807842255	Generator: loss 0.8746482133865356
# Epoch 11, batch 401/881:	Discriminator: real loss 0.18240006268024445, fake loss 0.20780575275421143	Generator: loss 0.8635837435722351
# Epoch 11, batch 451/881:	Discriminator: real loss 0.18999885022640228, fake loss 0.18588006496429443	Generator: loss 0.8543637990951538
# Epoch 11, batch 501/881:	Discriminator: real loss 0.18636253476142883, fake loss 0.1987367421388626	Generator: loss 0.8775467872619629
# Epoch 11, batch 551/881:	Discriminator: real loss 0.1755462884902954, fake loss 0.21276059746742249	Generator: loss 0.8622285723686218
# Epoch 11, batch 601/881:	Discriminator: real loss 0.1862816959619522, fake loss 0.18910232186317444	Generator: loss 0.8908252716064453
# Epoch 11, batch 651/881:	Discriminator: real loss 0.18951672315597534, fake loss 0.19222253561019897	Generator: loss 0.8802927732467651
# Epoch 11, batch 701/881:	Discriminator: real loss 0.21080580353736877, fake loss 0.20602905750274658	Generator: loss 0.8231523633003235
# Epoch 11, batch 751/881:	Discriminator: real loss 0.19605764746665955, fake loss 0.18840381503105164	Generator: loss 0.8678154945373535
# Epoch 11, batch 801/881:	Discriminator: real loss 0.18173646926879883, fake loss 0.19510723650455475	Generator: loss 0.8948419094085693
# Epoch 11, batch 851/881:	Discriminator: real loss 0.19194671511650085, fake loss 0.19701558351516724	Generator: loss 0.8570079803466797
# Epoch 12, batch 1/881:	Discriminator: real loss 0.18326659500598907, fake loss 0.19089815020561218	Generator: loss 0.8708564043045044
# Epoch 12, batch 51/881:	Discriminator: real loss 0.21021664142608643, fake loss 0.19940152764320374	Generator: loss 0.8828717470169067
# Epoch 12, batch 101/881:	Discriminator: real loss 0.1769590973854065, fake loss 0.18155604600906372	Generator: loss 0.8914454579353333
# Epoch 12, batch 151/881:	Discriminator: real loss 0.18055373430252075, fake loss 0.1879054605960846	Generator: loss 0.8633275032043457
# Epoch 12, batch 201/881:	Discriminator: real loss 0.20165370404720306, fake loss 0.2030450999736786	Generator: loss 0.8878707885742188
# Epoch 12, batch 251/881:	Discriminator: real loss 0.20951023697853088, fake loss 0.19806088507175446	Generator: loss 0.8801518678665161
# Epoch 12, batch 301/881:	Discriminator: real loss 0.1933353692293167, fake loss 0.18876183032989502	Generator: loss 0.893630862236023
# Epoch 12, batch 351/881:	Discriminator: real loss 0.19552308320999146, fake loss 0.19313277304172516	Generator: loss 0.9003766179084778
# Epoch 12, batch 401/881:	Discriminator: real loss 0.19150039553642273, fake loss 0.19970984756946564	Generator: loss 0.8527333736419678
# Epoch 12, batch 451/881:	Discriminator: real loss 0.18833360075950623, fake loss 0.18388892710208893	Generator: loss 0.858750581741333
# Epoch 12, batch 501/881:	Discriminator: real loss 0.1850237250328064, fake loss 0.19637519121170044	Generator: loss 0.873706579208374
# Epoch 12, batch 551/881:	Discriminator: real loss 0.17758095264434814, fake loss 0.18978823721408844	Generator: loss 0.8790030479431152
# Epoch 12, batch 601/881:	Discriminator: real loss 0.19265379011631012, fake loss 0.20575547218322754	Generator: loss 0.8972980976104736
# Epoch 12, batch 651/881:	Discriminator: real loss 0.18278059363365173, fake loss 0.19438806176185608	Generator: loss 0.8621821403503418
# Epoch 12, batch 701/881:	Discriminator: real loss 0.1982489824295044, fake loss 0.18920674920082092	Generator: loss 0.8863942623138428
# Epoch 12, batch 751/881:	Discriminator: real loss 0.2016145884990692, fake loss 0.1966893970966339	Generator: loss 0.8991222381591797
# Epoch 12, batch 801/881:	Discriminator: real loss 0.1873670220375061, fake loss 0.18713407218456268	Generator: loss 0.8785035610198975
# Epoch 12, batch 851/881:	Discriminator: real loss 0.19948028028011322, fake loss 0.19013601541519165	Generator: loss 0.8911879062652588
# Epoch 13, batch 1/881:	Discriminator: real loss 0.19596171379089355, fake loss 0.1936524212360382	Generator: loss 0.8991395831108093
# Epoch 13, batch 51/881:	Discriminator: real loss 0.21072709560394287, fake loss 0.18829575181007385	Generator: loss 0.942761242389679
# Epoch 13, batch 101/881:	Discriminator: real loss 0.19076794385910034, fake loss 0.20461249351501465	Generator: loss 0.855090856552124
# Epoch 13, batch 151/881:	Discriminator: real loss 0.20715896785259247, fake loss 0.19131138920783997	Generator: loss 0.8747438192367554
# Epoch 13, batch 201/881:	Discriminator: real loss 0.20250150561332703, fake loss 0.19778898358345032	Generator: loss 0.8890689611434937
# Epoch 13, batch 251/881:	Discriminator: real loss 0.20256555080413818, fake loss 0.18340444564819336	Generator: loss 0.8600269556045532
# Epoch 13, batch 301/881:	Discriminator: real loss 0.18386206030845642, fake loss 0.19796660542488098	Generator: loss 0.8791276216506958
# Epoch 13, batch 351/881:	Discriminator: real loss 0.18181580305099487, fake loss 0.19195780158042908	Generator: loss 0.8953030109405518
# Epoch 13, batch 401/881:	Discriminator: real loss 0.2005954086780548, fake loss 0.19128650426864624	Generator: loss 0.8664038181304932
# Epoch 13, batch 451/881:	Discriminator: real loss 0.19435815513134003, fake loss 0.1914348304271698	Generator: loss 0.9067074060440063
# Epoch 13, batch 501/881:	Discriminator: real loss 0.1944587230682373, fake loss 0.1868712306022644	Generator: loss 0.8872920274734497
# Epoch 13, batch 551/881:	Discriminator: real loss 0.19098417460918427, fake loss 0.20917215943336487	Generator: loss 0.8964043855667114
# Epoch 13, batch 601/881:	Discriminator: real loss 0.1889386773109436, fake loss 0.19181716442108154	Generator: loss 0.8561065196990967
# Epoch 13, batch 651/881:	Discriminator: real loss 0.19089524447917938, fake loss 0.1880989670753479	Generator: loss 0.8689368963241577
# Epoch 13, batch 701/881:	Discriminator: real loss 0.20066145062446594, fake loss 0.19263790547847748	Generator: loss 0.8956301212310791
# Epoch 13, batch 751/881:	Discriminator: real loss 0.19720983505249023, fake loss 0.1803475022315979	Generator: loss 0.8736766576766968
# Epoch 13, batch 801/881:	Discriminator: real loss 0.20015528798103333, fake loss 0.19441843032836914	Generator: loss 0.8694413900375366
# Epoch 13, batch 851/881:	Discriminator: real loss 0.19145405292510986, fake loss 0.17414991557598114	Generator: loss 0.9031448364257812
# Epoch 14, batch 1/881:	Discriminator: real loss 0.19066181778907776, fake loss 0.1952003389596939	Generator: loss 0.8715716600418091
# Epoch 14, batch 51/881:	Discriminator: real loss 0.17615634202957153, fake loss 0.19064870476722717	Generator: loss 0.945986270904541
# Epoch 14, batch 101/881:	Discriminator: real loss 0.1945522427558899, fake loss 0.19826063513755798	Generator: loss 0.8856582641601562
# Epoch 14, batch 151/881:	Discriminator: real loss 0.1989801526069641, fake loss 0.1944778561592102	Generator: loss 0.902493953704834
# Epoch 14, batch 201/881:	Discriminator: real loss 0.18065714836120605, fake loss 0.1965005099773407	Generator: loss 0.8828283548355103
# Epoch 14, batch 251/881:	Discriminator: real loss 0.19574546813964844, fake loss 0.17899422347545624	Generator: loss 0.8798462152481079
# Epoch 14, batch 301/881:	Discriminator: real loss 0.1838691234588623, fake loss 0.18814176321029663	Generator: loss 0.8999807238578796
# Epoch 14, batch 351/881:	Discriminator: real loss 0.19346997141838074, fake loss 0.19608727097511292	Generator: loss 0.8907349109649658
# Epoch 14, batch 401/881:	Discriminator: real loss 0.18517790734767914, fake loss 0.18298441171646118	Generator: loss 0.8721268177032471
# Epoch 14, batch 451/881:	Discriminator: real loss 0.19997820258140564, fake loss 0.19335982203483582	Generator: loss 0.9177282452583313
# Epoch 14, batch 501/881:	Discriminator: real loss 0.19147345423698425, fake loss 0.17075349390506744	Generator: loss 0.9102765321731567
# Epoch 14, batch 551/881:	Discriminator: real loss 0.17753982543945312, fake loss 0.18705835938453674	Generator: loss 0.8856076002120972
# Epoch 14, batch 601/881:	Discriminator: real loss 0.20117121934890747, fake loss 0.20262277126312256	Generator: loss 0.8706313371658325
# Epoch 14, batch 651/881:	Discriminator: real loss 0.18116196990013123, fake loss 0.18470340967178345	Generator: loss 0.8721721172332764
# Epoch 14, batch 701/881:	Discriminator: real loss 0.20017032325267792, fake loss 0.18727871775627136	Generator: loss 0.9021040201187134
# Epoch 14, batch 751/881:	Discriminator: real loss 0.1937953680753708, fake loss 0.17650967836380005	Generator: loss 0.8796899914741516
# Epoch 14, batch 801/881:	Discriminator: real loss 0.18481385707855225, fake loss 0.19000466167926788	Generator: loss 0.8568264245986938
# Epoch 14, batch 851/881:	Discriminator: real loss 0.1928151696920395, fake loss 0.19638997316360474	Generator: loss 0.8864346742630005
# Epoch 15, batch 1/881:	Discriminator: real loss 0.20309633016586304, fake loss 0.19043710827827454	Generator: loss 0.8698492050170898
# Epoch 15, batch 51/881:	Discriminator: real loss 0.20022515952587128, fake loss 0.18736505508422852	Generator: loss 0.8941224217414856
# Epoch 15, batch 101/881:	Discriminator: real loss 0.18661731481552124, fake loss 0.2031065672636032	Generator: loss 0.8829025030136108
# Epoch 15, batch 151/881:	Discriminator: real loss 0.20102649927139282, fake loss 0.20211264491081238	Generator: loss 0.9166145920753479
# Epoch 15, batch 201/881:	Discriminator: real loss 0.19697850942611694, fake loss 0.20805533230304718	Generator: loss 0.9019193649291992
# Epoch 15, batch 251/881:	Discriminator: real loss 0.1901882439851761, fake loss 0.18925997614860535	Generator: loss 0.8854119777679443
# Epoch 15, batch 301/881:	Discriminator: real loss 0.18973353505134583, fake loss 0.19178640842437744	Generator: loss 0.9000515341758728
# Epoch 15, batch 351/881:	Discriminator: real loss 0.18392840027809143, fake loss 0.20061132311820984	Generator: loss 0.8666241765022278
# Epoch 15, batch 401/881:	Discriminator: real loss 0.19473722577095032, fake loss 0.20524367690086365	Generator: loss 0.899542510509491
# Epoch 15, batch 451/881:	Discriminator: real loss 0.19331768155097961, fake loss 0.21240827441215515	Generator: loss 0.8784520626068115
# Epoch 15, batch 501/881:	Discriminator: real loss 0.18952961266040802, fake loss 0.18413886427879333	Generator: loss 0.8994908332824707
# Epoch 15, batch 551/881:	Discriminator: real loss 0.20143267512321472, fake loss 0.19795623421669006	Generator: loss 0.8894411325454712
# Epoch 15, batch 601/881:	Discriminator: real loss 0.19948133826255798, fake loss 0.1917729377746582	Generator: loss 0.8864821195602417
# Epoch 15, batch 651/881:	Discriminator: real loss 0.2037631720304489, fake loss 0.20536552369594574	Generator: loss 0.8784091472625732
# Epoch 15, batch 701/881:	Discriminator: real loss 0.19088611006736755, fake loss 0.19685977697372437	Generator: loss 0.8993223309516907
# Epoch 15, batch 751/881:	Discriminator: real loss 0.20700737833976746, fake loss 0.19786198437213898	Generator: loss 0.8835269808769226
# Epoch 15, batch 801/881:	Discriminator: real loss 0.21397969126701355, fake loss 0.18822208046913147	Generator: loss 0.909645676612854
# Epoch 15, batch 851/881:	Discriminator: real loss 0.177182137966156, fake loss 0.18919411301612854	Generator: loss 0.8810070157051086
# Epoch 16, batch 1/881:	Discriminator: real loss 0.20222073793411255, fake loss 0.2043202519416809	Generator: loss 0.8850860595703125
# Epoch 16, batch 51/881:	Discriminator: real loss 0.18911951780319214, fake loss 0.20408913493156433	Generator: loss 0.8890698552131653
# Epoch 16, batch 101/881:	Discriminator: real loss 0.19028201699256897, fake loss 0.20225676894187927	Generator: loss 0.9032922387123108
# Epoch 16, batch 151/881:	Discriminator: real loss 0.1785021424293518, fake loss 0.17681312561035156	Generator: loss 0.9115673303604126
# Epoch 16, batch 201/881:	Discriminator: real loss 0.20424704253673553, fake loss 0.20179839432239532	Generator: loss 0.8911340236663818
# Epoch 16, batch 251/881:	Discriminator: real loss 0.20341584086418152, fake loss 0.18370026350021362	Generator: loss 0.8575799465179443
# Epoch 16, batch 301/881:	Discriminator: real loss 0.18010301887989044, fake loss 0.19189384579658508	Generator: loss 0.8882986307144165
# Epoch 16, batch 351/881:	Discriminator: real loss 0.20036199688911438, fake loss 0.19478678703308105	Generator: loss 0.8977329134941101
# Epoch 16, batch 401/881:	Discriminator: real loss 0.1880241185426712, fake loss 0.19758249819278717	Generator: loss 0.8936716318130493
# Epoch 16, batch 451/881:	Discriminator: real loss 0.19182536005973816, fake loss 0.2038252055644989	Generator: loss 0.9138588309288025
# Epoch 16, batch 501/881:	Discriminator: real loss 0.1840704083442688, fake loss 0.20013660192489624	Generator: loss 0.891492486000061
# Epoch 16, batch 551/881:	Discriminator: real loss 0.18806830048561096, fake loss 0.19841361045837402	Generator: loss 0.8783448338508606
# Epoch 16, batch 601/881:	Discriminator: real loss 0.18534095585346222, fake loss 0.19176828861236572	Generator: loss 0.8930622339248657
# Epoch 16, batch 651/881:	Discriminator: real loss 0.19468557834625244, fake loss 0.19240646064281464	Generator: loss 0.8950662612915039
# Epoch 16, batch 701/881:	Discriminator: real loss 0.18361318111419678, fake loss 0.18368422985076904	Generator: loss 0.8904613256454468
# Epoch 16, batch 751/881:	Discriminator: real loss 0.19967907667160034, fake loss 0.20539984107017517	Generator: loss 0.9116249084472656
# Epoch 16, batch 801/881:	Discriminator: real loss 0.20353573560714722, fake loss 0.1733284443616867	Generator: loss 0.9082822799682617
# Epoch 16, batch 851/881:	Discriminator: real loss 0.2036725878715515, fake loss 0.20908328890800476	Generator: loss 0.8831278085708618
# Epoch 17, batch 1/881:	Discriminator: real loss 0.18344658613204956, fake loss 0.18115746974945068	Generator: loss 0.9210443496704102
# Epoch 17, batch 51/881:	Discriminator: real loss 0.20097005367279053, fake loss 0.18865951895713806	Generator: loss 0.8638496398925781
# Epoch 17, batch 101/881:	Discriminator: real loss 0.1893095076084137, fake loss 0.19281384348869324	Generator: loss 0.9146534204483032
# Epoch 17, batch 151/881:	Discriminator: real loss 0.20092599093914032, fake loss 0.20125974714756012	Generator: loss 0.8664529323577881
# Epoch 17, batch 201/881:	Discriminator: real loss 0.2029946744441986, fake loss 0.1921277493238449	Generator: loss 0.8724966049194336
# Epoch 17, batch 251/881:	Discriminator: real loss 0.19565019011497498, fake loss 0.18943239748477936	Generator: loss 0.8798011541366577
# Epoch 17, batch 301/881:	Discriminator: real loss 0.207453191280365, fake loss 0.18423274159431458	Generator: loss 0.8923301100730896
# Epoch 17, batch 351/881:	Discriminator: real loss 0.20824195444583893, fake loss 0.20519521832466125	Generator: loss 0.8983436822891235
# Epoch 17, batch 401/881:	Discriminator: real loss 0.1889512836933136, fake loss 0.191444531083107	Generator: loss 0.8930456638336182
# Epoch 17, batch 451/881:	Discriminator: real loss 0.19470557570457458, fake loss 0.19858905673027039	Generator: loss 0.8723130822181702
# Epoch 17, batch 501/881:	Discriminator: real loss 0.17757973074913025, fake loss 0.17427396774291992	Generator: loss 0.9120333790779114
# Epoch 17, batch 551/881:	Discriminator: real loss 0.1884777545928955, fake loss 0.19310253858566284	Generator: loss 0.8682705163955688
# Epoch 17, batch 601/881:	Discriminator: real loss 0.17826871573925018, fake loss 0.1872296929359436	Generator: loss 0.9244281053543091
# Epoch 17, batch 651/881:	Discriminator: real loss 0.1950540989637375, fake loss 0.18243631720542908	Generator: loss 0.9163735508918762
# Epoch 17, batch 701/881:	Discriminator: real loss 0.18491707742214203, fake loss 0.18002605438232422	Generator: loss 0.9016808867454529
# Epoch 17, batch 751/881:	Discriminator: real loss 0.1865851879119873, fake loss 0.18650750815868378	Generator: loss 0.9007476568222046
# Epoch 17, batch 801/881:	Discriminator: real loss 0.19259291887283325, fake loss 0.19556298851966858	Generator: loss 0.8828257322311401
# Epoch 17, batch 851/881:	Discriminator: real loss 0.19003427028656006, fake loss 0.18266618251800537	Generator: loss 0.8757859468460083
# Epoch 18, batch 1/881:	Discriminator: real loss 0.20644477009773254, fake loss 0.20132479071617126	Generator: loss 0.8953710198402405
# Epoch 18, batch 51/881:	Discriminator: real loss 0.1916758269071579, fake loss 0.20000848174095154	Generator: loss 0.8997930884361267
# Epoch 18, batch 101/881:	Discriminator: real loss 0.19102875888347626, fake loss 0.18522332608699799	Generator: loss 0.876814603805542
# Epoch 18, batch 151/881:	Discriminator: real loss 0.18334752321243286, fake loss 0.18285948038101196	Generator: loss 0.9126816987991333
# Epoch 18, batch 201/881:	Discriminator: real loss 0.19878610968589783, fake loss 0.18802468478679657	Generator: loss 0.8958572149276733
# Epoch 18, batch 251/881:	Discriminator: real loss 0.2058614194393158, fake loss 0.19733268022537231	Generator: loss 0.8799625039100647
# Epoch 18, batch 301/881:	Discriminator: real loss 0.196059912443161, fake loss 0.19628213346004486	Generator: loss 0.9185464382171631
# Epoch 18, batch 351/881:	Discriminator: real loss 0.19611936807632446, fake loss 0.18934817612171173	Generator: loss 0.9151062965393066
# Epoch 18, batch 401/881:	Discriminator: real loss 0.18272222578525543, fake loss 0.19289496541023254	Generator: loss 0.8931055068969727
# Epoch 18, batch 451/881:	Discriminator: real loss 0.1864110827445984, fake loss 0.18791259825229645	Generator: loss 0.8861712217330933
# Epoch 18, batch 501/881:	Discriminator: real loss 0.19853141903877258, fake loss 0.18946170806884766	Generator: loss 0.9138994812965393
# Epoch 18, batch 551/881:	Discriminator: real loss 0.20508500933647156, fake loss 0.2056453377008438	Generator: loss 0.9380606412887573
# Epoch 18, batch 601/881:	Discriminator: real loss 0.1773255467414856, fake loss 0.19610963761806488	Generator: loss 0.8813630938529968
# Epoch 18, batch 651/881:	Discriminator: real loss 0.19275258481502533, fake loss 0.19372504949569702	Generator: loss 0.935420036315918
# Epoch 18, batch 701/881:	Discriminator: real loss 0.19557960331439972, fake loss 0.19703739881515503	Generator: loss 0.947639524936676
# Epoch 18, batch 751/881:	Discriminator: real loss 0.21003051102161407, fake loss 0.19226914644241333	Generator: loss 0.9161466360092163
# Epoch 18, batch 801/881:	Discriminator: real loss 0.21013237535953522, fake loss 0.20234337449073792	Generator: loss 0.8781179785728455
# Epoch 18, batch 851/881:	Discriminator: real loss 0.1879955232143402, fake loss 0.1935429573059082	Generator: loss 0.9058055281639099
# Epoch 19, batch 1/881:	Discriminator: real loss 0.1957467496395111, fake loss 0.20663200318813324	Generator: loss 0.8817956447601318
# Epoch 19, batch 51/881:	Discriminator: real loss 0.2007908821105957, fake loss 0.19491927325725555	Generator: loss 0.8943405747413635
# Epoch 19, batch 101/881:	Discriminator: real loss 0.1779974400997162, fake loss 0.1933097392320633	Generator: loss 0.907676100730896
# Epoch 19, batch 151/881:	Discriminator: real loss 0.20581196248531342, fake loss 0.19725777208805084	Generator: loss 0.8685570955276489
# Epoch 19, batch 201/881:	Discriminator: real loss 0.1819826364517212, fake loss 0.20155681669712067	Generator: loss 0.8745580911636353
# Epoch 19, batch 251/881:	Discriminator: real loss 0.18763278424739838, fake loss 0.18750722706317902	Generator: loss 0.9221034049987793
# Epoch 19, batch 301/881:	Discriminator: real loss 0.1841566562652588, fake loss 0.1773630678653717	Generator: loss 0.892959713935852
# Epoch 19, batch 351/881:	Discriminator: real loss 0.19035698473453522, fake loss 0.18098041415214539	Generator: loss 0.9018778204917908
# Epoch 19, batch 401/881:	Discriminator: real loss 0.1859872192144394, fake loss 0.19590884447097778	Generator: loss 0.9214174151420593
# Epoch 19, batch 451/881:	Discriminator: real loss 0.19250886142253876, fake loss 0.1769428551197052	Generator: loss 0.8964247703552246
# Epoch 19, batch 501/881:	Discriminator: real loss 0.18468531966209412, fake loss 0.19360646605491638	Generator: loss 0.8930389285087585
# Epoch 19, batch 551/881:	Discriminator: real loss 0.18698549270629883, fake loss 0.1970461905002594	Generator: loss 0.8742806911468506
# Epoch 19, batch 601/881:	Discriminator: real loss 0.18263542652130127, fake loss 0.18032723665237427	Generator: loss 0.8904812932014465
# Epoch 19, batch 651/881:	Discriminator: real loss 0.1867440938949585, fake loss 0.2080489993095398	Generator: loss 0.9319133162498474
# Epoch 19, batch 701/881:	Discriminator: real loss 0.18260431289672852, fake loss 0.18187864124774933	Generator: loss 0.9383386373519897
# Epoch 19, batch 751/881:	Discriminator: real loss 0.18415182828903198, fake loss 0.17215141654014587	Generator: loss 0.9113520979881287
# Epoch 19, batch 801/881:	Discriminator: real loss 0.1915377527475357, fake loss 0.1829317808151245	Generator: loss 0.9000890851020813
# Epoch 19, batch 851/881:	Discriminator: real loss 0.20784883201122284, fake loss 0.2055208384990692	Generator: loss 0.8925022482872009
# Epoch 20, batch 1/881:	Discriminator: real loss 0.1895601451396942, fake loss 0.20399752259254456	Generator: loss 0.8609730005264282
# Epoch 20, batch 51/881:	Discriminator: real loss 0.20163196325302124, fake loss 0.20735014975070953	Generator: loss 0.9017144441604614
# Epoch 20, batch 101/881:	Discriminator: real loss 0.19878406822681427, fake loss 0.2048453539609909	Generator: loss 0.8945885896682739
# Epoch 20, batch 151/881:	Discriminator: real loss 0.1942814588546753, fake loss 0.1923011839389801	Generator: loss 0.8854871988296509
# Epoch 20, batch 201/881:	Discriminator: real loss 0.1887713372707367, fake loss 0.18291783332824707	Generator: loss 0.9217756390571594
# Epoch 20, batch 251/881:	Discriminator: real loss 0.18586358428001404, fake loss 0.20549394190311432	Generator: loss 0.8918036222457886
# Epoch 20, batch 301/881:	Discriminator: real loss 0.18172213435173035, fake loss 0.19826945662498474	Generator: loss 0.919878363609314
# Epoch 20, batch 351/881:	Discriminator: real loss 0.19620418548583984, fake loss 0.18590408563613892	Generator: loss 0.8918137550354004
# Epoch 20, batch 401/881:	Discriminator: real loss 0.19656632840633392, fake loss 0.1864442229270935	Generator: loss 0.9121666550636292
# Epoch 20, batch 451/881:	Discriminator: real loss 0.20089663565158844, fake loss 0.18670302629470825	Generator: loss 0.9188604950904846
# Epoch 20, batch 501/881:	Discriminator: real loss 0.18864339590072632, fake loss 0.18920201063156128	Generator: loss 0.8768801689147949
# Epoch 20, batch 551/881:	Discriminator: real loss 0.2044539749622345, fake loss 0.19674794375896454	Generator: loss 0.8841923475265503
# Epoch 20, batch 601/881:	Discriminator: real loss 0.1881878674030304, fake loss 0.17475184798240662	Generator: loss 0.8980845212936401
# Epoch 20, batch 651/881:	Discriminator: real loss 0.2032342255115509, fake loss 0.1811319887638092	Generator: loss 0.9049255847930908
# ...
# Epoch 94, batch 401/881:	Discriminator: real loss 0.1923978626728058, fake loss 0.19816583395004272	Generator: loss 0.9824221134185791
# Epoch 94, batch 451/881:	Discriminator: real loss 0.18797165155410767, fake loss 0.18048913776874542	Generator: loss 0.9128658175468445
# Epoch 94, batch 501/881:	Discriminator: real loss 0.2039240598678589, fake loss 0.21405941247940063	Generator: loss 0.917655885219574
# Epoch 94, batch 551/881:	Discriminator: real loss 0.17680180072784424, fake loss 0.18781240284442902	Generator: loss 0.946536660194397
# Epoch 94, batch 601/881:	Discriminator: real loss 0.19134531915187836, fake loss 0.19563940167427063	Generator: loss 0.9449767470359802
# Epoch 94, batch 651/881:	Discriminator: real loss 0.18946993350982666, fake loss 0.19408264756202698	Generator: loss 0.9568040370941162
# Epoch 94, batch 701/881:	Discriminator: real loss 0.20254984498023987, fake loss 0.1749146729707718	Generator: loss 1.0007901191711426
# Epoch 94, batch 751/881:	Discriminator: real loss 0.1908051073551178, fake loss 0.19863562285900116	Generator: loss 0.9568926095962524
# Epoch 94, batch 801/881:	Discriminator: real loss 0.19169706106185913, fake loss 0.16907337307929993	Generator: loss 0.9210605621337891
# Epoch 94, batch 851/881:	Discriminator: real loss 0.19054901599884033, fake loss 0.18979600071907043	Generator: loss 0.9278188943862915
# Epoch 95, batch 1/881:	Discriminator: real loss 0.18779124319553375, fake loss 0.1611306369304657	Generator: loss 0.9600249528884888
# Epoch 95, batch 51/881:	Discriminator: real loss 0.18896430730819702, fake loss 0.17103958129882812	Generator: loss 0.9720317125320435
# Epoch 95, batch 101/881:	Discriminator: real loss 0.1880682110786438, fake loss 0.17171086370944977	Generator: loss 0.9671909213066101
# Epoch 95, batch 151/881:	Discriminator: real loss 0.1751253604888916, fake loss 0.16966865956783295	Generator: loss 0.9807813167572021
# Epoch 95, batch 201/881:	Discriminator: real loss 0.1927577704191208, fake loss 0.1903361976146698	Generator: loss 0.9223977327346802
# Epoch 95, batch 251/881:	Discriminator: real loss 0.20517100393772125, fake loss 0.19148698449134827	Generator: loss 0.947370707988739
# Epoch 95, batch 301/881:	Discriminator: real loss 0.18609610199928284, fake loss 0.18630851805210114	Generator: loss 0.8751752376556396
# Epoch 95, batch 351/881:	Discriminator: real loss 0.17485390603542328, fake loss 0.18961602449417114	Generator: loss 0.9318777918815613
# Epoch 95, batch 401/881:	Discriminator: real loss 0.21680408716201782, fake loss 0.18312986195087433	Generator: loss 0.9616222381591797
# Epoch 95, batch 451/881:	Discriminator: real loss 0.17619818449020386, fake loss 0.18788538873195648	Generator: loss 0.9570145606994629
# Epoch 95, batch 501/881:	Discriminator: real loss 0.19313696026802063, fake loss 0.19271180033683777	Generator: loss 0.9709997177124023
# Epoch 95, batch 551/881:	Discriminator: real loss 0.2039458155632019, fake loss 0.1738799512386322	Generator: loss 0.9399800300598145
# Epoch 95, batch 601/881:	Discriminator: real loss 0.19083061814308167, fake loss 0.17557072639465332	Generator: loss 0.9206217527389526
# Epoch 95, batch 651/881:	Discriminator: real loss 0.19843712449073792, fake loss 0.19030576944351196	Generator: loss 0.9444066286087036
# Epoch 95, batch 701/881:	Discriminator: real loss 0.18544942140579224, fake loss 0.2071492075920105	Generator: loss 0.9225732088088989
# Epoch 95, batch 751/881:	Discriminator: real loss 0.19287240505218506, fake loss 0.19103184342384338	Generator: loss 0.9720602035522461
# Epoch 95, batch 801/881:	Discriminator: real loss 0.19659990072250366, fake loss 0.1720181107521057	Generator: loss 0.9908912181854248
# Epoch 95, batch 851/881:	Discriminator: real loss 0.18568678200244904, fake loss 0.18541216850280762	Generator: loss 0.9194274544715881
# Epoch 96, batch 1/881:	Discriminator: real loss 0.17345474660396576, fake loss 0.1833694577217102	Generator: loss 0.9165269136428833
# Epoch 96, batch 51/881:	Discriminator: real loss 0.1741059422492981, fake loss 0.16798269748687744	Generator: loss 0.9377551078796387
# Epoch 96, batch 101/881:	Discriminator: real loss 0.18326756358146667, fake loss 0.1665591597557068	Generator: loss 0.9532763957977295
# Epoch 96, batch 151/881:	Discriminator: real loss 0.19366788864135742, fake loss 0.16236889362335205	Generator: loss 0.9339732527732849
# Epoch 96, batch 201/881:	Discriminator: real loss 0.19367118179798126, fake loss 0.16291770339012146	Generator: loss 0.9579138159751892
# Epoch 96, batch 251/881:	Discriminator: real loss 0.21786239743232727, fake loss 0.1875508576631546	Generator: loss 0.9643712043762207
# Epoch 96, batch 301/881:	Discriminator: real loss 0.18773230910301208, fake loss 0.18069392442703247	Generator: loss 0.9673842191696167
# Epoch 96, batch 351/881:	Discriminator: real loss 0.17592105269432068, fake loss 0.16734957695007324	Generator: loss 0.961341381072998
# Epoch 96, batch 401/881:	Discriminator: real loss 0.17685672640800476, fake loss 0.17039774358272552	Generator: loss 0.9513961672782898
# Epoch 96, batch 451/881:	Discriminator: real loss 0.18785196542739868, fake loss 0.1903567612171173	Generator: loss 0.958175778388977
# Epoch 96, batch 501/881:	Discriminator: real loss 0.1942918598651886, fake loss 0.18898989260196686	Generator: loss 0.9018100500106812
# Epoch 96, batch 551/881:	Discriminator: real loss 0.21464936435222626, fake loss 0.17359860241413116	Generator: loss 0.988362729549408
# Epoch 96, batch 601/881:	Discriminator: real loss 0.20560075342655182, fake loss 0.1839277148246765	Generator: loss 0.9657406806945801
# Epoch 96, batch 651/881:	Discriminator: real loss 0.1963481605052948, fake loss 0.16528528928756714	Generator: loss 0.9587953686714172
# Epoch 96, batch 701/881:	Discriminator: real loss 0.21787503361701965, fake loss 0.15644225478172302	Generator: loss 0.9604483842849731
# Epoch 96, batch 751/881:	Discriminator: real loss 0.18190932273864746, fake loss 0.16330602765083313	Generator: loss 0.9790093898773193
# Epoch 96, batch 801/881:	Discriminator: real loss 0.1871044635772705, fake loss 0.18721787631511688	Generator: loss 0.9875451326370239
# Epoch 96, batch 851/881:	Discriminator: real loss 0.19736550748348236, fake loss 0.18253645300865173	Generator: loss 0.9235954284667969
# Epoch 97, batch 1/881:	Discriminator: real loss 0.19800987839698792, fake loss 0.1919013112783432	Generator: loss 0.9915430545806885
# Epoch 97, batch 51/881:	Discriminator: real loss 0.1958654671907425, fake loss 0.1805115044116974	Generator: loss 0.9805953502655029
# Epoch 97, batch 101/881:	Discriminator: real loss 0.17686516046524048, fake loss 0.18905997276306152	Generator: loss 0.9455952644348145
# Epoch 97, batch 151/881:	Discriminator: real loss 0.22086477279663086, fake loss 0.17775586247444153	Generator: loss 0.9374330639839172
# Epoch 97, batch 201/881:	Discriminator: real loss 0.20424050092697144, fake loss 0.19402925670146942	Generator: loss 0.9674294590950012
# Epoch 97, batch 251/881:	Discriminator: real loss 0.1875787079334259, fake loss 0.19283995032310486	Generator: loss 0.9316572546958923
# Epoch 97, batch 301/881:	Discriminator: real loss 0.18799017369747162, fake loss 0.18918243050575256	Generator: loss 1.0187044143676758
# Epoch 97, batch 351/881:	Discriminator: real loss 0.18716374039649963, fake loss 0.17224112153053284	Generator: loss 0.9702214002609253
# Epoch 97, batch 401/881:	Discriminator: real loss 0.18734398484230042, fake loss 0.19190733134746552	Generator: loss 1.0268081426620483
# Epoch 97, batch 451/881:	Discriminator: real loss 0.19408006966114044, fake loss 0.19443081319332123	Generator: loss 0.9522517323493958
# Epoch 97, batch 501/881:	Discriminator: real loss 0.1747092306613922, fake loss 0.16988030076026917	Generator: loss 0.9182219505310059
# Epoch 97, batch 551/881:	Discriminator: real loss 0.19428080320358276, fake loss 0.18291261792182922	Generator: loss 0.9570508003234863
# Epoch 97, batch 601/881:	Discriminator: real loss 0.18979866802692413, fake loss 0.17478270828723907	Generator: loss 0.9325834512710571
# Epoch 97, batch 651/881:	Discriminator: real loss 0.19060230255126953, fake loss 0.17255476117134094	Generator: loss 0.9323481917381287
# Epoch 97, batch 701/881:	Discriminator: real loss 0.20036150515079498, fake loss 0.1968146562576294	Generator: loss 0.9935632944107056
# Epoch 97, batch 751/881:	Discriminator: real loss 0.1921297311782837, fake loss 0.18954095244407654	Generator: loss 0.9810040593147278
# Epoch 97, batch 801/881:	Discriminator: real loss 0.19491663575172424, fake loss 0.19158458709716797	Generator: loss 0.9524229764938354
# Epoch 97, batch 851/881:	Discriminator: real loss 0.19325995445251465, fake loss 0.18630042672157288	Generator: loss 0.9523468017578125
# Epoch 98, batch 1/881:	Discriminator: real loss 0.19583235681056976, fake loss 0.18775999546051025	Generator: loss 0.9676734209060669
# Epoch 98, batch 51/881:	Discriminator: real loss 0.193960502743721, fake loss 0.20371583104133606	Generator: loss 0.9402516484260559
# Epoch 98, batch 101/881:	Discriminator: real loss 0.2025543600320816, fake loss 0.1979978382587433	Generator: loss 0.9395641684532166
# Epoch 98, batch 151/881:	Discriminator: real loss 0.19479301571846008, fake loss 0.20545589923858643	Generator: loss 0.927776575088501
# Epoch 98, batch 201/881:	Discriminator: real loss 0.1768430769443512, fake loss 0.17167887091636658	Generator: loss 0.8978825211524963
# Epoch 98, batch 251/881:	Discriminator: real loss 0.1910042017698288, fake loss 0.17221581935882568	Generator: loss 0.9927489757537842
# Epoch 98, batch 301/881:	Discriminator: real loss 0.21105313301086426, fake loss 0.16169373691082	Generator: loss 0.9874250292778015
# Epoch 98, batch 351/881:	Discriminator: real loss 0.18726405501365662, fake loss 0.17580345273017883	Generator: loss 0.9571331739425659
# Epoch 98, batch 401/881:	Discriminator: real loss 0.18494218587875366, fake loss 0.2001330554485321	Generator: loss 0.9392471313476562
# Epoch 98, batch 451/881:	Discriminator: real loss 0.17625606060028076, fake loss 0.18196851015090942	Generator: loss 0.9826105237007141
# Epoch 98, batch 501/881:	Discriminator: real loss 0.18489402532577515, fake loss 0.1936204433441162	Generator: loss 0.9620583653450012
# Epoch 98, batch 551/881:	Discriminator: real loss 0.1916787177324295, fake loss 0.17577055096626282	Generator: loss 0.9201276302337646
# Epoch 98, batch 601/881:	Discriminator: real loss 0.21065163612365723, fake loss 0.19000914692878723	Generator: loss 0.9648846387863159
# Epoch 98, batch 651/881:	Discriminator: real loss 0.19483153522014618, fake loss 0.16747474670410156	Generator: loss 0.9720823168754578
# Epoch 98, batch 701/881:	Discriminator: real loss 0.18353848159313202, fake loss 0.1865030825138092	Generator: loss 0.918277382850647
# Epoch 98, batch 751/881:	Discriminator: real loss 0.1988513171672821, fake loss 0.19512903690338135	Generator: loss 0.9818366765975952
# Epoch 98, batch 801/881:	Discriminator: real loss 0.20458942651748657, fake loss 0.17995283007621765	Generator: loss 1.0035157203674316
# Epoch 98, batch 851/881:	Discriminator: real loss 0.18681614100933075, fake loss 0.1874496340751648	Generator: loss 0.9461110234260559
# Epoch 99, batch 1/881:	Discriminator: real loss 0.1946222484111786, fake loss 0.16864779591560364	Generator: loss 0.9624028205871582
# Epoch 99, batch 51/881:	Discriminator: real loss 0.18480715155601501, fake loss 0.17433589696884155	Generator: loss 0.9591929316520691
# Epoch 99, batch 101/881:	Discriminator: real loss 0.17672641575336456, fake loss 0.17891472578048706	Generator: loss 0.9455952644348145
# Epoch 99, batch 151/881:	Discriminator: real loss 0.18389469385147095, fake loss 0.18654833734035492	Generator: loss 0.9690641760826111
# Epoch 99, batch 201/881:	Discriminator: real loss 0.1919160783290863, fake loss 0.1527210921049118	Generator: loss 0.9642534255981445
# Epoch 99, batch 251/881:	Discriminator: real loss 0.18819734454154968, fake loss 0.19877445697784424	Generator: loss 0.9891386032104492
# Epoch 99, batch 301/881:	Discriminator: real loss 0.18883416056632996, fake loss 0.1869826316833496	Generator: loss 0.9590192437171936
# Epoch 99, batch 351/881:	Discriminator: real loss 0.2074979543685913, fake loss 0.17633235454559326	Generator: loss 0.9426076412200928
# Epoch 99, batch 401/881:	Discriminator: real loss 0.17261961102485657, fake loss 0.18452292680740356	Generator: loss 0.9417214393615723
# Epoch 99, batch 451/881:	Discriminator: real loss 0.19167503714561462, fake loss 0.2125159054994583	Generator: loss 0.9501757025718689
# Epoch 99, batch 501/881:	Discriminator: real loss 0.17499491572380066, fake loss 0.1900758147239685	Generator: loss 0.9870832562446594
# Epoch 99, batch 551/881:	Discriminator: real loss 0.19801127910614014, fake loss 0.19158664345741272	Generator: loss 0.942257821559906
# Epoch 99, batch 601/881:	Discriminator: real loss 0.16923272609710693, fake loss 0.1784145087003708	Generator: loss 0.9723447561264038
# Epoch 99, batch 651/881:	Discriminator: real loss 0.2012978345155716, fake loss 0.18653245270252228	Generator: loss 1.0227818489074707
# Epoch 99, batch 701/881:	Discriminator: real loss 0.19031164050102234, fake loss 0.17957445979118347	Generator: loss 0.9758386611938477
# Epoch 99, batch 751/881:	Discriminator: real loss 0.1969732642173767, fake loss 0.18475478887557983	Generator: loss 0.9616222381591797
# Epoch 99, batch 801/881:	Discriminator: real loss 0.18380622565746307, fake loss 0.16341134905815125	Generator: loss 0.9940704703330994
# Epoch 99, batch 851/881:	Discriminator: real loss 0.19685079157352448, fake loss 0.19662067294120789	Generator: loss 0.9824436902999878
# Epoch 100, batch 1/881:	Discriminator: real loss 0.18663108348846436, fake loss 0.18152055144309998	Generator: loss 0.9054811596870422
# Epoch 100, batch 51/881:	Discriminator: real loss 0.1908644437789917, fake loss 0.17790216207504272	Generator: loss 0.9449494481086731
# Epoch 100, batch 101/881:	Discriminator: real loss 0.21150049567222595, fake loss 0.19290800392627716	Generator: loss 0.9825237989425659
# Epoch 100, batch 151/881:	Discriminator: real loss 0.194037526845932, fake loss 0.17373502254486084	Generator: loss 0.9565194845199585
# Epoch 100, batch 201/881:	Discriminator: real loss 0.1904798001050949, fake loss 0.18296264111995697	Generator: loss 0.968626081943512
# Epoch 100, batch 251/881:	Discriminator: real loss 0.19932149350643158, fake loss 0.18631571531295776	Generator: loss 1.0176925659179688
# Epoch 100, batch 301/881:	Discriminator: real loss 0.2064661979675293, fake loss 0.18993014097213745	Generator: loss 0.9682531952857971
# Epoch 100, batch 351/881:	Discriminator: real loss 0.18222807347774506, fake loss 0.16103653609752655	Generator: loss 0.9945707321166992
# Epoch 100, batch 401/881:	Discriminator: real loss 0.2053138166666031, fake loss 0.1757487654685974	Generator: loss 0.945875883102417
# Epoch 100, batch 451/881:	Discriminator: real loss 0.1764022558927536, fake loss 0.18064257502555847	Generator: loss 0.9477457404136658
# Epoch 100, batch 501/881:	Discriminator: real loss 0.181659996509552, fake loss 0.19337841868400574	Generator: loss 0.9400792717933655
# Epoch 100, batch 551/881:	Discriminator: real loss 0.20771467685699463, fake loss 0.18087399005889893	Generator: loss 0.9200985431671143
# Epoch 100, batch 601/881:	Discriminator: real loss 0.17974957823753357, fake loss 0.16462931036949158	Generator: loss 0.9585282206535339
# Epoch 100, batch 651/881:	Discriminator: real loss 0.2084357887506485, fake loss 0.2014077603816986	Generator: loss 0.9333842992782593
# Epoch 100, batch 701/881:	Discriminator: real loss 0.2023943066596985, fake loss 0.20053963363170624	Generator: loss 0.9622345566749573
# Epoch 100, batch 751/881:	Discriminator: real loss 0.18020707368850708, fake loss 0.18182805180549622	Generator: loss 0.9600623250007629
# Epoch 100, batch 801/881:	Discriminator: real loss 0.19419161975383759, fake loss 0.19584280252456665	Generator: loss 0.9719541072845459
# Epoch 100, batch 851/881:	Discriminator: real loss 0.1907578408718109, fake loss 0.1815374344587326	Generator: loss 0.9862858057022095

# %%
def show_generated(examples, n, c):
  fig = plt.figure(figsize=(c, n))
  for i in range(n*c):
    img = fig.add_subplot(n, c, i+1)
    plt.axis('off')
    plt.imshow(examples[i,:,:,0], cmap='gray_r')
  plt.show()

n = 10
c = 47

model = load_model('generator.h5')
noise, _ = generate_latent_noise(latent_dim, n*c)
labs = np.asarray([x for _ in range(n) for x in range(c)])

X = model.predict([noise, labs])
# scale from [-1, 1] to [0, 1]
X = (X + 1) / 2.0
x = np.squeeze(X[0])
plt.imshow(x)

show_generated(X, n, c)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
from google.colab import files

dflag = True
if dflag:
  files.download('generator.h5')
  files.download('gan.h5')
  files.download('discriminator.h5')
